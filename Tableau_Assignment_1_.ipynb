# %% [markdown]
# Web Series Analysis   Assignment Questions

# %%
# !pip install openpyxl

# %% [markdown]
#   NAME :- Web_Series_dataset
#
#  Column Description
#  Series ID – A unique identifier for each web series
#  Title – Name of the web series
#  Genre – Categorization of the series (e.g., Thriller, Drama, Comedy, Crime, Sci-Fi, Mystery)
#  Platform – The streaming service where the series is available (e.g., Netflix, Amazon Prime, Hotstar)
#  Seasons – The number of seasons for each series
#  Episodes – The total number of episodes in the series
#  IMDB Rating – The average user rating of the series on a scale of 1 to 10
#  Year – The release year of the series.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f8a09ac7-ef42-4df2-8a17-a012ce7fb2af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f8a09ac7-ef42-4df2-8a17-a012ce7fb2af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# Task 1: Trend of Web Series Released Per Year

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
#  Task 2: Distribution of IMDB Ratings Across Streaming Platforms
#  Goal: Use a Box Plot to analyze how IMDB ratings vary across different

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
Task 3: Top 5 Highest Rated Web Series

# %% [markdown]
# ![Screenshot 2025-07-15 104540.png](data:image/png;base64,...)

# %% [markdown]
#  Task 4: Genre Distribution of Web Series

# %% [markdown]
# ![Screenshot 2025-07-15 110001.png](data:image/png;base64,...)

# %% [markdown]
#  Task 5: Relationship Between Number of Episodes and IMDB Rating

# %% [markdown]
# ![Screenshot 2025-07-15 110423.png](data:image/png;base64,...)

# %% [markdown]
#  Task 6: Platform-Wise Average IMDB Rating by Genre

# %% [markdown]
# ![Screenshot 2025-07-15 110844.png](data:image/png;base64,...)

# %% [markdown]
# Task 7: Episodes Per Season Analysis

# %% [markdown]
# ![Screenshot 2025-07-15 111431.png](data:image/png;base64,...)

# %% [markdown]
#  Task 8: IMDB Rating vs. Number of Seasons (Grouped by Platform)

# %% [markdown]
# ![Screenshot 2025-07-15 111753.png](data:image/png;base64,...)

# %% [markdown]
# Task 9: Identify the Most Consistent Genre in Ratings

# %% [markdown]
# ![Screenshot 2025-07-15 112100.png](data:image/png;base64,...)

# %% [markdown]
# Task 10: Highlight Web Series with Above-Average Ratings in Each Genre
#  Goal: For each genre, list web series that have an IMDB rating higher than the genre’s average.

# %% [markdown]
# ![Screenshot 2025-07-15 112430.png](data:image/png;base64,...)
